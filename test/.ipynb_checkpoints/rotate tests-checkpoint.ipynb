# %% [markdown]
# You need to download the [Biopython](https://biopython.org/wiki/Download) library to manipulate the PDB, which can be done just with
#
# ```
# pip install biopython
# ```

# %%
import rmsd
from Bio import PDB
import numpy as np
from timeit import default_timer as timer

parser = PDB.PDBParser()
io = PDB.PDBIO()

# %% [markdown]
# Here I'm using this molecule: https://alphafold.ebi.ac.uk/entry/A0A5E8G9H8 and I renamed the pdb to `ecoli.pdb`.

# %%
pdb_name = "ecoli"

# %% [markdown]
# Now to generate 20 random rotations of `ecoli.pdb` and save them as `ecoli_rX.pdb`:
#
# (https://en.wikipedia.org/wiki/Rotation_matrix#In_three_dimensions)

# %%
def rot_x(theta):
    return np.array([
        [1, 0, 0],
        [0, np.cos(theta), -np.sin(theta)],
        [0, np.sin(theta), np.cos(theta)]
    ])

def rot_y(theta):
    return np.array([
        [np.cos(theta), 0, np.sin(theta)],
        [0, 1, 0],
        [-np.sin(theta), 0, np.cos(theta)]
    ])

def rot_z(theta):
    return np.array([
        [np.cos(theta), -np.sin(theta), 0],
        [np.sin(theta), np.cos(theta), 0],
        [0, 0, 1]
    ])

rotations = [rot_x, rot_y, rot_z]

# %% [markdown]
# The following code is modified from: https://stackoverflow.com/questions/47806879/how-to-move-protein-coordinates-with-respect-to-a-reference-frame

# %%
n = 20

for i in range(n):
    struct = parser.get_structure(pdb_name, f'{pdb_name}.pdb')
    
    rotation_axis = np.random.choice(rotations) # rotate around x, y, or z axis
    rotation_angle = np.random.uniform(low=0, high=2*np.pi) # angle b/t 0 and 2π
    
#     print("rotate axis: ", rotation_axis.__name__)
#     print("rotate angle: ", rotation_angle)

    rotation_matrix = rotation_axis(rotation_angle)
    
    # I think this also works: https://math.stackexchange.com/questions/442418/random-generation-of-rotation-matrices
#     rotation_matrix, _ = np.linalg.qr(np.random.rand(3, 3))
    
    for atom in struct.get_atoms():
        atom_C1 = atom.coord.copy()
        break

    for model in struct:
        for chain in model:
            for residue in chain:
                for atom in residue:
                    atom.transform(rotation_matrix, -atom_C1)

    io.set_structure(struct)
    io.save(f'{pdb_name}_r{i}.pdb')

# %% [markdown]
# Testing each rotation method on each rotation (show result and time):

# %%
methods = ["kabsch", "quaternion"]

for i in range(n):
    print(f'{pdb_name}_r{i}.pdb')
    for method in methods:
        print(f"  {method}")
        print("    result = ", end="")
        start = timer()
        rmsd.main(["-r", method, f'{pdb_name}.pdb', f'{pdb_name}_r{i}.pdb'])
        end = timer()
        print(f"    time   = {end - start} sec")
    print()
# Out:
# ecoli_r0.pdb
#   kabsch
#     result = 0.00040812597270293644
#     time   = 0.048885792000000095 sec
#   quaternion
#     result = 0.00040812597270292066
#     time   = 0.08238679099999979 sec
#
# ecoli_r1.pdb
#   kabsch
#     result = 0.0004194450067299636
#     time   = 0.04081750000000017 sec
#   quaternion
#     result = 0.0004194450067301782
#     time   = 0.06194683299999992 sec
#
# ecoli_r2.pdb
#   kabsch
#     result = 0.00041035940802890337
#     time   = 0.014217374999999866 sec
#   quaternion
#     result = 0.00041035940802979886
#     time   = 0.035016499999999784 sec
#
# ecoli_r3.pdb
#   kabsch
#     result = 0.00040865086767757664
#     time   = 0.013397416000000106 sec
#   quaternion
#     result = 0.00040865086767750676
#     time   = 0.035085374999999974 sec
#
# ecoli_r4.pdb
#   kabsch
#     result = 0.0004105978472259471
#     time   = 0.01331812500000007 sec
#   quaternion
#     result = 0.0004105978472253157
#     time   = 0.034309374999999864 sec
#
# ecoli_r5.pdb
#   kabsch
#     result = 0.0004062175753845837
#     time   = 0.013307082999999942 sec
#   quaternion
#     result = 0.00040621757538462444
#     time   = 0.034134250000000144 sec
#
# ecoli_r6.pdb
#   kabsch
#     result = 0.00040840453119409334
#     time   = 0.01409574999999963 sec
#   quaternion
#     result = 0.00040840453119409534
#     time   = 0.03662133400000034 sec
#
# ecoli_r7.pdb
#   kabsch
#     result = 0.00040979765339768973
#     time   = 0.014123209000000081 sec
#   quaternion
#     result = 0.0004097976533976929
#     time   = 0.03440391699999967 sec
#
# ecoli_r8.pdb
#   kabsch
#     result = 0.00040529000398024755
#     time   = 0.01329795899999997 sec
#   quaternion
#     result = 0.0004052900039801547
#     time   = 0.03422295799999997 sec
#
# ecoli_r9.pdb
#   kabsch
#     result = 0.0004065291926122669
#     time   = 0.013760709000000038 sec
#   quaternion
#     result = 0.00040652919261218866
#     time   = 0.0340487089999999 sec
#
# ecoli_r10.pdb
#   kabsch
#     result = 0.00040179868555633433
#     time   = 0.01375995899999971 sec
#   quaternion
#     result = 0.0004017986855564107
#     time   = 0.03573316599999998 sec
#
# ecoli_r11.pdb
#   kabsch
#     result = 0.00040789610248906204
#     time   = 0.014110499999999693 sec
#   quaternion
#     result = 0.00040789610248893014
#     time   = 0.03546633300000002 sec
#
# ecoli_r12.pdb
#   kabsch
#     result = 0.00041187378548776917
#     time   = 0.015131374999999725 sec
#   quaternion
#     result = 0.00041187378548866813
#     time   = 0.03494216700000008 sec
#
# ecoli_r13.pdb
#   kabsch
#     result = 0.00040914492561269815
#     time   = 0.014200458999999999 sec
#   quaternion
#     result = 0.0004091449256125909
#     time   = 0.03440783299999994 sec
#
# ecoli_r14.pdb
#   kabsch
#     result = 0.0004081691210293419
#     time   = 0.013779500000000056 sec
#   quaternion
#     result = 0.0004081691210292072
#     time   = 0.0344911670000001 sec
#
# ecoli_r15.pdb
#   kabsch
#     result = 0.00040654486394767767
#     time   = 0.014642999999999962 sec
#   quaternion
#     result = 0.00040654486394783564
#     time   = 0.03479579200000016 sec
#
# ecoli_r16.pdb
#   kabsch
#     result = 0.00040810484381290747
#     time   = 0.014040249999999865 sec
#   quaternion
#     result = 0.0004081048438124634
#     time   = 0.034774875000000094 sec
#
# ecoli_r17.pdb
#   kabsch
#     result = 0.0004017905587851584
#     time   = 0.0137905410000001 sec
#   quaternion
#     result = 0.00040179055878507253
#     time   = 0.03465512500000001 sec
#
# ecoli_r18.pdb
#   kabsch
#     result = 0.0004112722961416411
#     time   = 0.013681875000000066 sec
#   quaternion
#     result = 0.0004112722961417966
#     time   = 0.034916042000000314 sec
#
# ecoli_r19.pdb
#   kabsch
#     result = 0.0004038217702499392
#     time   = 0.014831125000000167 sec
#   quaternion
#     result = 0.00040382177025031845
#     time   = 0.035301417000000335 sec
